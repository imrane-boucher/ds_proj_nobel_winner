# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### Librairies

# %%
import pandas as pd
from functools import reduce
import re
import numpy as np

# %% [markdown]
# ### import Data

# %%
df_cit = pd.read_csv('data/nb_cit_cleaning.csv')
df_downl = pd.read_csv('data/nb_downloads.csv')
df_pages = pd.read_csv('data/nb_pages.csv')
df_stu = pd.read_csv('data/nb_students.csv')
df_works = pd.read_csv('data/nb_works.csv')
df_hind = pd.read_csv('data/h_index.csv')
df_clark = pd.read_csv('data/clark_medal.csv')
df_vn = pd.read_csv('data/von_neumann.csv')
df_nobel = pd.read_csv('data/nobel_prize_winners.csv')

dfs = [df_downl, df_pages, df_stu, df_works, df_hind]

# %%
df_cit.head()
# Out:
#    Rank                                             Author  Score  \
# 0     1  Andrei Shleifer Department of Economics, Harva...  48826
# 1     2  James J. Heckman Department of Economics, Univ...  34146
# 2     3  Robert J. Barro Department of Economics, Harva...  31421
# 3     4  Robert F. Engle IIIFinance Department, Stern S...  28370
# 4     5  Eugene F. Fama Sr.Booth School of Business, Un...  27760
#
#        Author_clean
# 0   Andrei Shleifer
# 1  James J. Heckman
# 2   Robert J. Barro
# 3   Robert F. Engle
# 4    Eugene F. Fama

# %%
# cleaning Author columns
for df in dfs:
    df['Author'] = df['Author'].apply(lambda x: x.replace('  ', ' '))
    df['Author_clean'] = df['Author'].apply(lambda x: x.split(' ',3)[0:3] if '.' in x else x.split(' ',2)[0:2])
    df['Author_clean'] = df['Author_clean'].apply(lambda x: ' '.join(x))
    df.drop('Author', axis=1, inplace=True)

# %%
df_downl.head()
# Out:
#    Rank  Score    Author_clean
# 0     1   7515   Christopher F
# 1     2   7462    Jeffrey Marc
# 2     3   6565        Ben Jann
# 3     4   6537  Daron Acemoglu
# 4     5   6424    Nicholas Cox

# %%
df_works.head()
# Out:
#    Rank  Score     Author_clean
# 0     1   1656       Simplice A
# 1     2   1383  Michael McAleer
# 2     3   1320    Peter Nijkamp
# 3     4   1270     Rangan Gupta
# 4     5    940  Pierre Pestieau

# %%
# renaming dataframes columns:
df_col_names = ['nb_downl', 'nb_pages', 'nb_students', 'nb_works', 'h_index']

# %%
for df, col in zip(dfs,df_col_names):
    df.rename(columns={'Score': col}, inplace=True)
df_cit.rename(columns={'Score':'nb_cit'}, inplace=True)

# %%
# process for merging my dataframes

# 1: add a Surname column in each df

# 2: remove duplicates in each df

# 3: merge them on "Surname"

# 4: count how many nobel prize winners are left in the final dataframe

# %%
# 1:
df_cit['Surname'] = df_cit['Author_clean'].str.split(' ')
df_cit['Surname'] = df_cit['Surname'].str[-1]
df_cit['First'] = df_cit['Author_clean'].str.split(' ').str[0]

for df in dfs:
    df['Surname'] = df['Author_clean'].str.split(' ')
    df['Surname'] = df['Surname'].str[-1]
    df['First'] = df['Author_clean'].str.split(' ').str[0]
df_cit.shape
# Out:
# (2944, 6)

# %%
# 2:
df_cit = df_cit.drop_duplicates(subset=['Surname', 'First'], keep='first' ) 
# checking there's no duplicates left
sum(df_cit.pivot_table(index=['Surname'], aggfunc='size') > 1)

for df in dfs:
    df = df.drop_duplicates(subset=['Surname', 'First'], keep='first')
    print('nb_duplicates :',sum(df.pivot_table(index=['Surname'], aggfunc='size') > 1))
    print('shapes :', df.shape)
# Out:
# nb_duplicates : 203
# shapes : (2934, 5)
# nb_duplicates : 234
# shapes : (2946, 5)
# nb_duplicates : 235
# shapes : (2928, 6)
# nb_duplicates : 212
# shapes : (2965, 5)
# nb_duplicates : 278
# shapes : (3402, 5)

# %%
# 3:
df_merged = reduce(lambda df_left,df_right: pd.merge(df_left, df_right, on=['Surname', 'First'],
                                              how='inner'), dfs)
df_merged2 = df_merged.drop_duplicates(subset=['Surname', 'First'], keep='first')

# %%
df_merged2.shape
# Out:
# (669, 18)

# %%
df_merged2.head()
# Out:
#    Rank_x  nb_downl      Author_clean_x   Surname        First  Rank_y  \
# 0       1      7515       Christopher F         F  Christopher    1367
# 1       2      7462        Jeffrey Marc      Marc      Jeffrey    1440
# 2       4      6537      Daron Acemoglu  Acemoglu        Daron      10
# 3       6      6290  Joseph E. Stiglitz  Stiglitz       Joseph       7
# 4       7      5632           John List      List         John      33
#
#    nb_pages      Author_clean_y  Rank_x  nb_students  Students  \
# 0      1099       Christopher F     328       374.56      10.0
# 1      1079        Jeffrey Marc     974      1037.32       4.0
# 2      5349      Daron Acemoglu      28        36.10      23.0
# 3      5753  Joseph E. Stiglitz      84        89.12       6.0
# 4      3642           John List     349       387.06       5.0
#
#        Author_clean_x  Rank_y  nb_works      Author_clean_y  Rank  h_index  \
# 0       Christopher F      95       415       Christopher F  1063       21
# 1        Jeffrey Marc     749       214        Jeffrey Marc   299       31
# 2      Daron Acemoglu      14       645      Daron Acemoglu     5       72
# 3  Joseph E. Stiglitz      17       643  Joseph E. Stiglitz     5       72
# 4           John List      10       681           John List    19       56
#
#          Author_clean
# 0       Christopher F
# 1        Jeffrey Marc
# 2      Daron Acemoglu
# 3  Joseph E. Stiglitz
# 4           John List

# %%
# add nber citations
df_result = pd.merge(df_merged2, df_cit, on=["Surname","First"],how="inner")

# %%
df_result.shape
# Out:
# (641, 22)

# %%
df_result.head()
# Out:
#    Rank_x  nb_downl      Author_clean_x   Surname        First  Rank_y  \
# 0       1      7515       Christopher F         F  Christopher    1367
# 1       2      7462        Jeffrey Marc      Marc      Jeffrey    1440
# 2       4      6537      Daron Acemoglu  Acemoglu        Daron      10
# 3       6      6290  Joseph E. Stiglitz  Stiglitz       Joseph       7
# 4       7      5632           John List      List         John      33
#
#    nb_pages      Author_clean_y  Rank_x  nb_students  ...  Rank_y nb_works  \
# 0      1099       Christopher F     328       374.56  ...      95      415
# 1      1079        Jeffrey Marc     974      1037.32  ...     749      214
# 2      5349      Daron Acemoglu      28        36.10  ...      14      645
# 3      5753  Joseph E. Stiglitz      84        89.12  ...      17      643
# 4      3642           John List     349       387.06  ...      10      681
#
#        Author_clean_y  Rank_x h_index      Author_clean_x  Rank_y  \
# 0       Christopher F    1063      21       Christopher F     699
# 1        Jeffrey Marc     299      31        Jeffrey Marc      83
# 2      Daron Acemoglu       5      72      Daron Acemoglu       9
# 3  Joseph E. Stiglitz       5      72  Joseph E. Stiglitz       7
# 4           John List      19      56           John List      74
#
#                                               Author  nb_cit  \
# 0  Christopher F Baum Department of Economics, Bo...    3062
# 1  Jeffrey Marc Wooldridge Economics Department, ...   10615
# 2  Daron Acemoglu Economics Department, Massachus...   24703
# 3  Joseph E. Stiglitz Finance and Economics Depar...   25947
# 4  John List Department of Economics, University ...   11165
#
#        Author_clean_y
# 0       Christopher F
# 1        Jeffrey Marc
# 2      Daron Acemoglu
# 3  Joseph E. Stiglitz
# 4           John List
#
# [5 rows x 22 columns]

# %%
# 4:
df_nobel['First'] = df_nobel['Author'].str.split(' ').str[0]
df_nobel['Surname'] = df_nobel['Author'].str.split(' ').str[-1]
print('nber of nobel prize winners: ', sum(df_result['Surname'].isin(df_nobel['Surname'])))
print('percentage of nobel prize winners in data:', sum(df_result['Surname'].isin(df_nobel['Surname']))/df_result.shape[0])
# Out:
# nber of nobel prize winners:  37
# percentage of nobel prize winners in data: 0.057722308892355696

# %%
# Next steps:

# TODO: cleaning df_result
# TODO: adding columns for clark medal and von neumann
# TODO: add columns nobel prize winners
# TODO: feature engeneere to get the affiliate university & the country of the economist
# TODO: reduce to size of our data to 300 economists
# TODO: clean the jupyter notebook

# %%
# TODO: cleaning df_result
df_result.tail()
# Out:
#      Rank_x  nb_downl       Author_clean_x       Surname    First  Rank_y  \
# 636    2881       363  Fabien Postel-Vinay  Postel-Vinay   Fabien    1809
# 637    2896       362        Martin Paldam        Paldam   Martin    1729
# 638    2896       362  Michael Christopher   Christopher  Michael    2400
# 639    2909       361       Alan M. Rugman        Rugman     Alan    1979
# 640    2924       360    Thomas R. Palfrey       Palfrey   Thomas     283
#
#      nb_pages       Author_clean_y  Rank_x  nb_students  ...  Rank_y nb_works  \
# 636       964  Fabien Postel-Vinay    1722      1814.29  ...    1770      143
# 637       985        Martin Paldam     720       764.92  ...    2935      111
# 638       840  Michael Christopher     218       240.06  ...     903      197
# 639       920       Alan M. Rugman    2301      2390.19  ...    2648      117
# 640      1995    Thomas R. Palfrey    1382      1473.91  ...     519      247
#
#           Author_clean_y  Rank_x h_index       Author_clean_x  Rank_y  \
# 636  Fabien Postel-Vinay    1403      19  Fabien Postel-Vinay    1424
# 637        Martin Paldam    1403      19        Martin Paldam    1820
# 638  Michael Christopher    1403      19  Michael Christopher    1877
# 639       Alan M. Rugman    1063      21       Alan M. Rugman    1669
# 640    Thomas R. Palfrey     299      31    Thomas R. Palfrey     500
#
#                                                 Author  nb_cit  \
# 636  Fabien Postel-Vinay Department of Economics, U...    1766
# 637  Martin Paldam School of Economics and Manageme...    1435
# 638  Michael Christopher Burda Institut für Wirtsch...    1398
# 639                                   Alan M. Rugman †    1548
# 640  Thomas R. Palfrey Division of Social Sciences,...    3725
#
#           Author_clean_y
# 636  Fabien Postel-Vinay
# 637        Martin Paldam
# 638  Michael Christopher
# 639       Alan M. Rugman
# 640    Thomas R. Palfrey
#
# [5 rows x 22 columns]

# %%
df_result = df_result.drop(['Rank_x', 'Author_clean_x','Rank_y'], axis=1)
df_result.columns
# Out:
# Index(['nb_downl', 'Surname', 'First', 'nb_pages', 'Author_clean_y',
#        'nb_students', 'Students', 'nb_works', 'Author_clean_y', 'h_index',
#        'Author', 'nb_cit', 'Author_clean_y'],
#       dtype='object')

# %%
df_result = df_result.loc[:, ~df_result.columns.duplicated()]

# %%
df_result.drop(columns=['nb_students'], axis=1, inplace=True)

# %%
df_result.tail()
# Out:
#      nb_downl       Surname    First  nb_pages       Author_clean_y  Students  \
# 636       363  Postel-Vinay   Fabien       964  Fabien Postel-Vinay       3.0
# 637       362        Paldam   Martin       985        Martin Paldam       1.0
# 638       362   Christopher  Michael       840  Michael Christopher      15.0
# 639       361        Rugman     Alan       920       Alan M. Rugman       0.5
# 640       360       Palfrey   Thomas      1995    Thomas R. Palfrey       1.0
#
#      nb_works  h_index                                             Author  \
# 636       143       19  Fabien Postel-Vinay Department of Economics, U...
# 637       111       19  Martin Paldam School of Economics and Manageme...
# 638       197       19  Michael Christopher Burda Institut für Wirtsch...
# 639       117       21                                   Alan M. Rugman †
# 640       247       31  Thomas R. Palfrey Division of Social Sciences,...
#
#      nb_cit
# 636    1766
# 637    1435
# 638    1398
# 639    1548
# 640    3725

# %%
df_result.rename(columns={'Author_clean_y': 'Author_clean'}, inplace=True)
df_result.columns
# Out:
# Index(['nb_downl', 'Surname', 'First', 'nb_pages', 'Author_clean', 'Students',
#        'nb_works', 'h_index', 'Author', 'nb_cit'],
#       dtype='object')

# %%
df_result.isnull().any()
# Out:
# nb_downl        False
# Surname         False
# First           False
# nb_pages        False
# Author_clean    False
# Students        False
# nb_works        False
# h_index         False
# Author          False
# nb_cit          False
# dtype: bool

# %%
# TODO: adding columns for clark medal and von neumann
# cleaning clark dataset
ls_clark = list(df_clark['Medalists'])
ls_clark_new = []
for x in ls_clark:
    new_str = re.sub('[0-9]','',x)
    new_str = new_str.replace('[]','')
    ls_clark_new.append(new_str)
df_clark['Medalists'] = ls_clark_new
df_clark['Medalists'].tail()
# Out:
# 37    Yuliy Sannikov
# 38    Dave Donaldson
# 39      Parag Pathak
# 40      Emi Nakamura
# 41      Melissa Dell
# Name: Medalists, dtype: object

# %%
df_clark['Surname'] = df_clark['Medalists'].str.split(' ').str[-1]
df_clark['First'] = df_clark['Medalists'].str.split(' ').str[0]
df_clark.head()
# Out:
#    Year            Medalists       Institution (at time of receipt)  \
# 0  1947       Paul Samuelson  Massachusetts Institute of Technology
# 1  1949  Kenneth E. Boulding                 University of Michigan
# 2  1951      Milton Friedman                  University of Chicago
# 3  1955          James Tobin                        Yale University
# 4  1957        Kenneth Arrow                    Stanford University
#
#        Alma mater (PhD)    Nationality  Nobel Prize    Surname    First
# 0    Harvard University  United States       1970.0  Samuelson     Paul
# 1  University of Oxford  United States          NaN   Boulding  Kenneth
# 2   Columbia University  United States       1976.0   Friedman   Milton
# 3    Harvard University  United States       1981.0      Tobin    James
# 4   Columbia University  United States       1972.0      Arrow  Kenneth

# %%
# building boolean for clark
df_result_clark = df_result.copy()

df_boolclark = (df_result_clark['Author_clean'].isin(df_clark['Medalists'])) \
             | (df_result_clark['First'].isin(df_clark['First']) & df_result_clark['Surname'].isin(df_clark['Surname']))

print('number of clark medal winners in our dataset:',df_boolclark.sum())
print('percentage of clark medal winners present in our dataset:',round(df_boolclark.sum() / df_clark.shape[0], 2))                                
df_clark.shape
# Out:
# number of clark medal winners in our dataset: 23
# percentage of clark medal winners present in our dataset: 0.55
# (42, 8)

# %%
# cleaning von neuman dataset
ls_vn = list(df_vn['Recipient'])
ls_vn_new = []
for x in ls_vn:
    new_str = re.sub('[0-9]','',x)
    new_str = new_str.replace('[]','')
    ls_vn_new.append(new_str)
df_vn['Recipient'] = ls_vn_new
df_vn['Recipient'].tail()
# Out:
# 20    Matthew O. Jackson
# 21         Alvin E. Roth
# 22     Richard H. Thaler
# 23           Dani Rodrik
# 24           Susan Athey
# Name: Recipient, dtype: object

# %%
# building boolean for von neumann
df_vn['Surname'] = df_vn['Recipient'].str.split('.')
df_vn['Surname'] = df_vn['Recipient'].str.strip().str.split(' ')
df_vn['Surname'] = df_vn['Surname'].str[-1]

df_vn['First'] = df_vn['Recipient'].str.split(' ').str[0]
df_vn.head()
# Out:
#    Year              Recipient                             Institution  \
# 0  1995          John Harsanyi                             UC Berkeley
# 1  1996             Hal Varian                  University of Michigan
# 2  1997           János Kornai  Harvard University; Collegium Budapest
# 3  1998            Jean Tirole            Toulouse School of Economics
# 4  1999  Oliver E. Williamson                              UC Berkeley
#
#      Nationality     Surname   First
# 0  United States    Harsanyi    John
# 1  United States      Varian     Hal
# 2        Hungary      Kornai   János
# 3         France      Tirole    Jean
# 4  United States  Williamson  Oliver

# %%
df_result_vn = df_result.copy()

df_boolvn = (df_result_vn['Author_clean'].isin(df_vn['Recipient'])) \
             | (df_result_vn['First'].isin(df_vn['First']) & df_result_vn['Surname'].isin(df_vn['Surname']))

print('number of von neumann awards winners in our dataset:',df_boolvn.sum())
print('percentage of von neumann awards winners present in our dataset:',round(df_boolvn.sum() / df_vn.shape[0], 2))                                
df_boolvn.shape
# Out:
# number of von neumann awards winners in our dataset: 12
# percentage of von neumann awards winners present in our dataset: 0.48
# (641,)

# %%
# add column von neuman award
df_result['vn_award'] = 0
df_result['vn_award'][df_boolvn] = 1
# Out:
# C:\Users\imran\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_result['vn_award'].value_counts()
# Out:
# 0    629
# 1     12
# Name: vn_award, dtype: int64

# %%
# add column clark metal
df_result['clark'] = 0
df_result['clark'][df_boolclark] = 1
# Out:
# C:\Users\imran\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_result['clark'].value_counts()
# Out:
# 0    618
# 1     23
# Name: clark, dtype: int64

# %%
df_result.head()
# Out:
#    nb_downl   Surname        First  nb_pages        Author_clean  Students  \
# 0      7515         F  Christopher      1099       Christopher F      10.0
# 1      7462      Marc      Jeffrey      1079        Jeffrey Marc       4.0
# 2      6537  Acemoglu        Daron      5349      Daron Acemoglu      23.0
# 3      6290  Stiglitz       Joseph      5753  Joseph E. Stiglitz       6.0
# 4      5632      List         John      3642           John List       5.0
#
#    nb_works  h_index                                             Author  \
# 0       415       21  Christopher F Baum Department of Economics, Bo...
# 1       214       31  Jeffrey Marc Wooldridge Economics Department, ...
# 2       645       72  Daron Acemoglu Economics Department, Massachus...
# 3       643       72  Joseph E. Stiglitz Finance and Economics Depar...
# 4       681       56  John List Department of Economics, University ...
#
#    nb_cit  vn_award  clark
# 0    3062         0      0
# 1   10615         0      0
# 2   24703         1      1
# 3   25947         0      1
# 4   11165         0      0

# %%
# TODO: add columns nobel prize winners

# %%
df_result_nobel = df_result.copy()

df_boolnobel = (df_result_nobel['Author_clean'].isin(df_nobel['Author'])) \
             | (df_result_nobel['First'].isin(df_nobel['First']) & df_result_nobel['Surname'].isin(df_nobel['Surname']))

print('number of nobel price winners in our dataset:',df_boolnobel.sum())
print('percentage of nobel price winners present in our dataset:',round(df_boolnobel.sum() / df_nobel.shape[0], 2))                                
df_boolnobel.shape
# Out:
# number of nobel price winners in our dataset: 30
# percentage of nobel price winners present in our dataset: 0.36
# (641,)

# %%
df_result['nobel'] = 0
df_result['nobel'][df_boolnobel] = 1
df_result[df_result['nobel'] == 1]
# Out:
# C:\Users\imran\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      nb_downl     Surname        First  nb_pages         Author_clean  \
# 3        6290    Stiglitz       Joseph      5753   Joseph E. Stiglitz
# 6        5097     Heckman        James      5018     James J. Heckman
# 7        4891    Nordhaus      William      1793  William D. Nordhaus
# 9        3968     Sargent       Thomas      3439    Thomas J. Sargent
# 10       3956     Krugman         Paul      1636      Paul R. Krugman
# 12       3842      Becker         Gary      1323       Gary S. Becker
# 21       3356       Lucas       Robert      1391      Robert E. Lucas
# 31       2924      Tirole         Jean      4439          Jean Tirole
# 35       2567       Engle       Robert      2116      Robert F. Engle
# 40       2444       Tobin        James      1114          James Tobin
# 46       2371     Shiller       Robert      1941    Robert J. Shiller
# 50       2301       Duflo       Esther       969         Esther Duflo
# 52       2238       Arrow      Kenneth      1127     Kenneth J. Arrow
# 60       2107        Sims  Christopher      1131     Christopher Sims
# 64       2067   Samuelson         Paul      2204    Paul A. Samuelson
# 106      1687    Prescott       Edward      1550   Edward C. Prescott
# 127      1598      Deaton        Angus      1924      Angus S. Deaton
# 133      1573       Solow       Robert      1090      Robert M. Solow
# 139      1531    Friedman       Milton       877      Milton Friedman
# 226      1058       Smith       Vernon      2338      Vernon L. Smith
# 237      1032     Diamond        Peter      1972     Peter A. Diamond
# 259       966        Hart       Oliver       835       Oliver D. Hart
# 279       905  Modigliani       Franco      1166    Franco Modigliani
# 321       802     Myerson        Roger      1295     Roger B. Myerson
# 335       783    Buchanan        James      1562    James M. Buchanan
# 402       664        Roth        Alvin      2174        Alvin E. Roth
# 497       551      Phelps       Edmund      1499     Edmund S. Phelps
# 564       460      Miller         Paul      2009       Paul W. Miller
# 593       421      Maskin         Eric      1411       Eric S. Maskin
# 629       379      Selten     Reinhard      1265      Reinhard Selten
#
#      Students  nb_works  h_index  \
# 3         6.0       643       72
# 6        26.0       645       86
# 7         0.5       208       34
# 9        19.0       365       50
# 10        8.5       199       49
# 12       10.5       172       49
# 21       31.5       127       42
# 31        5.0       478       74
# 35       12.5       230       58
# 40        6.0       194       22
# 46        3.5       312       45
# 50        8.5       223       42
# 52       18.5       145       28
# 60       28.0       145       35
# 64        2.0       237       25
# 106      37.5       250       44
# 127       4.5       302       53
# 133      11.0       149       24
# 139       5.5       213       27
# 226       3.0       244       38
# 237       7.5       214       37
# 259       4.5       161       37
# 279       3.0       113       19
# 321       6.0       147       25
# 335       2.0       194       20
# 402       9.0       232       40
# 497       0.5       164       21
# 564       0.5       213       22
# 593      45.5       195       43
# 629       3.5       159       25
#
#                                                 Author  nb_cit  vn_award  \
# 3    Joseph E. Stiglitz Finance and Economics Depar...   25947         0
# 6    James J. Heckman Department of Economics, Univ...   34146         0
# 7    William D. Nordhaus Cowles Foundation for Rese...    5083         0
# 9    Thomas J. Sargent Department of Economics, New...    9609         0
# 10   Paul R. Krugman Woodrow Wilson School of Publi...   16124         0
# 12                                    Gary S. Becker †   20728         1
# 21   Robert E. Lucas Jr.Department of Economics, Un...   18980         0
# 31   Jean Tirole Institut d'Économie Industrielle (...   24483         1
# 35   Robert F. Engle IIIFinance Department, Stern S...   28370         0
# 40                                       James Tobin †    3983         0
# 46   Robert J. Shiller Cowles Foundation for Resear...   10032         0
# 50   Esther Duflo Economics Department, Massachuset...   10006         1
# 52                                  Kenneth J. Arrow †    6198         1
# 60   Christopher Sims Department of Economics, Prin...   11682         0
# 64                                 Paul A. Samuelson †    4692         0
# 106  Edward C. Prescott Department of Economics, W....   15057         0
# 127  Angus S. Deaton Leonard D. Schaeffer Center fo...   12367         0
# 133  Robert M. Solow Economics Department, Massachu...    5823         0
# 139                                  Milton Friedman †    6094         0
# 226  Vernon L. Smith Economic Science Institute (ES...    5591         0
# 237  Peter A. Diamond Economics Department, Massach...    7159         0
# 259  Oliver D. Hart Department of Economics, Harvar...   11040         0
# 279                                Franco Modigliani †    2509         0
# 321  Roger B. Myerson Harris School of Public Polic...    4184         0
# 335                                James M. Buchanan †    1896         0
# 402  Alvin E. Roth Department of Economics, Stanfor...    6263         1
# 497  Edmund S. Phelps Department of Economics, Scho...    2675         0
# 564                                   Paul W. Miller †    1811         0
# 593  Eric S. Maskin Department of Economics, Harvar...    7515         0
# 629                                  Reinhard Selten †    2476         0
#
#      clark  nobel
# 3        1      1
# 6        1      1
# 7        0      1
# 9        0      1
# 10       1      1
# 12       1      1
# 21       0      1
# 31       0      1
# 35       0      1
# 40       1      1
# 46       0      1
# 50       1      1
# 52       1      1
# 60       0      1
# 64       1      1
# 106      0      1
# 127      0      1
# 133      1      1
# 139      1      1
# 226      0      1
# 237      0      1
# 259      0      1
# 279      0      1
# 321      0      1
# 335      0      1
# 402      0      1
# 497      0      1
# 564      0      1
# 593      0      1
# 629      0      1

# %%
# TODO: feature engeneere to get the affiliate university & the country of the economist
for i in range(10,20):
    print(df_result['Author'].iloc[i])
# Out:
# Paul R. Krugman Woodrow Wilson School of Public and International Affairs, Princeton University, Princeton, New Jersey (USA)
# Ross Levine National Bureau of Economic Research (NBER), Cambridge, Massachusetts (USA)
# Gary S. Becker †
# John Michael van Reenen Centre for Economic Performance (CEP), London School of Economics (LSE), London, United Kingdom
# Ben S. Bernanke Economic Studies, Brookings Institution, Washington, District of Columbia (USA)
# Barry Julian Eichengreen Department of Economics, University of California-Berkeley, Berkeley, California (USA)
# Oded Galor Economics Department, Brown University, Providence, Rhode Island (USA)
# Rafal Weron Katedra Badań Operacyjnych i Inteligencji Biznesowej, Politechnika Wrocławska, Wrocław, Poland
# Dani Rodrik Kennedy School of Government, Harvard University, Cambridge, Massachusetts (USA)
# Andrei Shleifer Department of Economics, Harvard University, Cambridge, Massachusetts (USA)National Bureau of Economic Research (NBER), Cambridge, Massachusetts (USA)

# %%
df_country = df_result['Author'].copy()
df_country_test = df_country.str.split(',').str[-1]

# %%
#df_country_test["USA" in df_country_test] = "United States"
df_country_test = df_country_test.apply(lambda x: x.split(' ')[-1] if "USA" in x else x)

# %%
#print(df_country_test.value_counts())
df_country_test2 = df_country_test.str.replace('.+†', 'None')

# %%
df_country_test2.value_counts()
df_country_test2.rename('Country', axis=1, inplace=True)
# Out:
# 0                (USA)
# 1                (USA)
# 2                (USA)
# 3                (USA)
# 4                (USA)
#             ...
# 636     United Kingdom
# 637            Denmark
# 638            Germany
# 639               None
# 640              (USA)
# Name: Country, Length: 641, dtype: object

# %%
df_result = pd.concat([df_result, df_country_test2], axis=1)

# %%
df_result.head()
# Out:
#    nb_downl   Surname        First  nb_pages        Author_clean  Students  \
# 0      7515         F  Christopher      1099       Christopher F      10.0
# 1      7462      Marc      Jeffrey      1079        Jeffrey Marc       4.0
# 2      6537  Acemoglu        Daron      5349      Daron Acemoglu      23.0
# 3      6290  Stiglitz       Joseph      5753  Joseph E. Stiglitz       6.0
# 4      5632      List         John      3642           John List       5.0
#
#    nb_works  h_index                                             Author  \
# 0       415       21  Christopher F Baum Department of Economics, Bo...
# 1       214       31  Jeffrey Marc Wooldridge Economics Department, ...
# 2       645       72  Daron Acemoglu Economics Department, Massachus...
# 3       643       72  Joseph E. Stiglitz Finance and Economics Depar...
# 4       681       56  John List Department of Economics, University ...
#
#    nb_cit  vn_award  clark  nobel Country
# 0    3062         0      0      0   (USA)
# 1   10615         0      0      0   (USA)
# 2   24703         1      1      0   (USA)
# 3   25947         0      1      1   (USA)
# 4   11165         0      0      0   (USA)

# %%
# TODO: feature engeneere to get the affiliate university of the economist
top10_shangai = ['University of Chicago', 'Harvard University', 'Massachusetts Institute of Technology',
                 'University of California-Berkeley','Princeton University', 'Columbia University',
                 'Stanford University', 'New York University','London School of Economics', 'Yale University']
#df_result_uni = df_result.copy()
df_result['top10_shangai_yn'] = df_result['Author'].apply(lambda x: 1 if any(uni in x for uni in top10_shangai) else 0)
df_result.head(10)
# Out:
#    nb_downl   Surname        First  nb_pages         Author_clean  Students  \
# 0      7515         F  Christopher      1099        Christopher F      10.0
# 1      7462      Marc      Jeffrey      1079         Jeffrey Marc       4.0
# 2      6537  Acemoglu        Daron      5349       Daron Acemoglu      23.0
# 3      6290  Stiglitz       Joseph      5753   Joseph E. Stiglitz       6.0
# 4      5632      List         John      3642            John List       5.0
# 5      5426     Barro       Robert      2705      Robert J. Barro       7.0
# 6      5097   Heckman        James      5018     James J. Heckman      26.0
# 7      4891  Nordhaus      William      1793  William D. Nordhaus       0.5
# 8      4525    Hashem            M      3607             M Hashem       4.0
# 9      3968   Sargent       Thomas      3439    Thomas J. Sargent      19.0
#
#    nb_works  h_index                                             Author  \
# 0       415       21  Christopher F Baum Department of Economics, Bo...
# 1       214       31  Jeffrey Marc Wooldridge Economics Department, ...
# 2       645       72  Daron Acemoglu Economics Department, Massachus...
# 3       643       72  Joseph E. Stiglitz Finance and Economics Depar...
# 4       681       56  John List Department of Economics, University ...
# 5       329       65  Robert J. Barro Department of Economics, Harva...
# 6       645       86  James J. Heckman Department of Economics, Univ...
# 7       208       34  William D. Nordhaus Cowles Foundation for Rese...
# 8       649       57  M Hashem Pesaran Department of Economics, Univ...
# 9       365       50  Thomas J. Sargent Department of Economics, New...
#
#    nb_cit  vn_award  clark  nobel Country  top10_shangai_yn
# 0    3062         0      0      0   (USA)                 0
# 1   10615         0      0      0   (USA)                 0
# 2   24703         1      1      0   (USA)                 1
# 3   25947         0      1      1   (USA)                 1
# 4   11165         0      0      0   (USA)                 1
# 5   31421         0      0      0   (USA)                 1
# 6   34146         0      1      1   (USA)                 1
# 7    5083         0      0      1   (USA)                 1
# 8   23850         0      0      0   (USA)                 0
# 9    9609         0      0      1   (USA)                 1

# %%
for i in range(10):
    print(df_result['Author'].iloc[i])
# Out:
# Christopher F Baum Department of Economics, Boston College, Chestnut Hill, Massachusetts (USA)
# Jeffrey Marc Wooldridge Economics Department, Michigan State University, East Lansing, Michigan (USA)
# Daron Acemoglu Economics Department, Massachusetts Institute of Technology (MIT), Cambridge, Massachusetts (USA)
# Joseph E. Stiglitz Finance and Economics Department, Graduate School of Business, Columbia University, New York City, New York (USA)
# John List Department of Economics, University of Chicago, Chicago, Illinois (USA)
# Robert J. Barro Department of Economics, Harvard University, Cambridge, Massachusetts (USA)
# James J. Heckman Department of Economics, University of Chicago, Chicago, Illinois (USA)
# William D. Nordhaus Cowles Foundation for Research in Economics, Yale University, New Haven, Connecticut (USA)Economics Department, Yale University, New Haven, Connecticut (USA)
# M Hashem Pesaran Department of Economics, University of Southern California, Los Angeles, California (USA)
# Thomas J. Sargent Department of Economics, New York University (NYU), New York City, New York (USA)

# %%
df_result['top10_shangai_yn'].value_counts()
# Out:
# 0    466
# 1    175
# Name: top10_shangai_yn, dtype: int64

# %%
# last cleaning step : manually complete the affiliate university plus country of dead nobel winners economists (9)
# list of economists :
# Gary S. Becker, James Tobin, Kenneth J. Arrow, Milton Friedman, Paul A. Samuelson, Franco Modigliani, James M. Buchanan
# Paul W. Miller, Reinhard Selten

# correct country
nobel_names = ['Gary S. Becker', 'James Tobin', 'Kenneth J. Arrow', 'Milton Friedman', 'Paul A. Samuelson',
                    'Franco Modigliani', 'James M. Buchanan', 'Paul W. Miller', 'Reinhard Selten']
nobel_countries = ['(USA)', '(USA)', '(USA)', '(USA)', '(USA)', '(USA)', 
                   'Italy', '(USA)', 'Germany' ]
nobel_uni = [1, 1, 1, 1, 1,
             1, 0, 0, 0]
for name, ctry, uni in zip(nobel_names, nobel_countries, nobel_uni):
    df_result['Country'][df_result['Author_clean'] == name] = ctry
    df_result['top10_shangai_yn'][df_result['Author_clean'] == name] = uni
df_result[df_result['nobel'] == 1]
# Out:
# C:\Users\imran\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\imran\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#      nb_downl     Surname        First  nb_pages         Author_clean  \
# 3        6290    Stiglitz       Joseph      5753   Joseph E. Stiglitz
# 6        5097     Heckman        James      5018     James J. Heckman
# 7        4891    Nordhaus      William      1793  William D. Nordhaus
# 9        3968     Sargent       Thomas      3439    Thomas J. Sargent
# 10       3956     Krugman         Paul      1636      Paul R. Krugman
# 12       3842      Becker         Gary      1323       Gary S. Becker
# 21       3356       Lucas       Robert      1391      Robert E. Lucas
# 31       2924      Tirole         Jean      4439          Jean Tirole
# 35       2567       Engle       Robert      2116      Robert F. Engle
# 40       2444       Tobin        James      1114          James Tobin
# 46       2371     Shiller       Robert      1941    Robert J. Shiller
# 50       2301       Duflo       Esther       969         Esther Duflo
# 52       2238       Arrow      Kenneth      1127     Kenneth J. Arrow
# 60       2107        Sims  Christopher      1131     Christopher Sims
# 64       2067   Samuelson         Paul      2204    Paul A. Samuelson
# 106      1687    Prescott       Edward      1550   Edward C. Prescott
# 127      1598      Deaton        Angus      1924      Angus S. Deaton
# 133      1573       Solow       Robert      1090      Robert M. Solow
# 139      1531    Friedman       Milton       877      Milton Friedman
# 226      1058       Smith       Vernon      2338      Vernon L. Smith
# 237      1032     Diamond        Peter      1972     Peter A. Diamond
# 259       966        Hart       Oliver       835       Oliver D. Hart
# 279       905  Modigliani       Franco      1166    Franco Modigliani
# 321       802     Myerson        Roger      1295     Roger B. Myerson
# 335       783    Buchanan        James      1562    James M. Buchanan
# 402       664        Roth        Alvin      2174        Alvin E. Roth
# 497       551      Phelps       Edmund      1499     Edmund S. Phelps
# 564       460      Miller         Paul      2009       Paul W. Miller
# 593       421      Maskin         Eric      1411       Eric S. Maskin
# 629       379      Selten     Reinhard      1265      Reinhard Selten
#
#      Students  nb_works  h_index  \
# 3         6.0       643       72
# 6        26.0       645       86
# 7         0.5       208       34
# 9        19.0       365       50
# 10        8.5       199       49
# 12       10.5       172       49
# 21       31.5       127       42
# 31        5.0       478       74
# 35       12.5       230       58
# 40        6.0       194       22
# 46        3.5       312       45
# 50        8.5       223       42
# 52       18.5       145       28
# 60       28.0       145       35
# 64        2.0       237       25
# 106      37.5       250       44
# 127       4.5       302       53
# 133      11.0       149       24
# 139       5.5       213       27
# 226       3.0       244       38
# 237       7.5       214       37
# 259       4.5       161       37
# 279       3.0       113       19
# 321       6.0       147       25
# 335       2.0       194       20
# 402       9.0       232       40
# 497       0.5       164       21
# 564       0.5       213       22
# 593      45.5       195       43
# 629       3.5       159       25
#
#                                                 Author  nb_cit  vn_award  \
# 3    Joseph E. Stiglitz Finance and Economics Depar...   25947         0
# 6    James J. Heckman Department of Economics, Univ...   34146         0
# 7    William D. Nordhaus Cowles Foundation for Rese...    5083         0
# 9    Thomas J. Sargent Department of Economics, New...    9609         0
# 10   Paul R. Krugman Woodrow Wilson School of Publi...   16124         0
# 12                                    Gary S. Becker †   20728         1
# 21   Robert E. Lucas Jr.Department of Economics, Un...   18980         0
# 31   Jean Tirole Institut d'Économie Industrielle (...   24483         1
# 35   Robert F. Engle IIIFinance Department, Stern S...   28370         0
# 40                                       James Tobin †    3983         0
# 46   Robert J. Shiller Cowles Foundation for Resear...   10032         0
# 50   Esther Duflo Economics Department, Massachuset...   10006         1
# 52                                  Kenneth J. Arrow †    6198         1
# 60   Christopher Sims Department of Economics, Prin...   11682         0
# 64                                 Paul A. Samuelson †    4692         0
# 106  Edward C. Prescott Department of Economics, W....   15057         0
# 127  Angus S. Deaton Leonard D. Schaeffer Center fo...   12367         0
# 133  Robert M. Solow Economics Department, Massachu...    5823         0
# 139                                  Milton Friedman †    6094         0
# 226  Vernon L. Smith Economic Science Institute (ES...    5591         0
# 237  Peter A. Diamond Economics Department, Massach...    7159         0
# 259  Oliver D. Hart Department of Economics, Harvar...   11040         0
# 279                                Franco Modigliani †    2509         0
# 321  Roger B. Myerson Harris School of Public Polic...    4184         0
# 335                                James M. Buchanan †    1896         0
# 402  Alvin E. Roth Department of Economics, Stanfor...    6263         1
# 497  Edmund S. Phelps Department of Economics, Scho...    2675         0
# 564                                   Paul W. Miller †    1811         0
# 593  Eric S. Maskin Department of Economics, Harvar...    7515         0
# 629                                  Reinhard Selten †    2476         0
#
#      clark  nobel  Country  top10_shangai_yn
# 3        1      1    (USA)                 1
# 6        1      1    (USA)                 1
# 7        0      1    (USA)                 1
# 9        0      1    (USA)                 1
# 10       1      1    (USA)                 1
# 12       1      1    (USA)                 1
# 21       0      1    (USA)                 1
# 31       0      1   France                 0
# 35       0      1    (USA)                 1
# 40       1      1    (USA)                 1
# 46       0      1    (USA)                 1
# 50       1      1    (USA)                 1
# 52       1      1    (USA)                 1
# 60       0      1    (USA)                 1
# 64       1      1    (USA)                 1
# 106      0      1    (USA)                 0
# 127      0      1    (USA)                 0
# 133      1      1    (USA)                 1
# 139      1      1    (USA)                 1
# 226      0      1    (USA)                 0
# 237      0      1    (USA)                 1
# 259      0      1    (USA)                 1
# 279      0      1    (USA)                 1
# 321      0      1    (USA)                 1
# 335      0      1    Italy                 0
# 402      0      1    (USA)                 1
# 497      0      1    (USA)                 1
# 564      0      1    (USA)                 0
# 593      0      1    (USA)                 1
# 629      0      1  Germany                 0

# %%
# TODO: Reduce the size of the dataset to 300 rows

# %%
# subest a dataframe with no nobel winners so we can randomly remove rows in it 
df_no_nobel = df_result[df_result['nobel'] == 0]
df_no_nobel.shape
# Out:
# (611, 15)

# %%
print('we want to remove {} rows' .format(df_result.shape[0] - 400))
# Out:
# we want to remove 241 rows

# %%
np.random.seed(10)

remove_n = 241
drop_indices = np.random.choice(df_no_nobel.index, remove_n, replace=False)
df_subset = df_result.drop(drop_indices)

# %%
df_subset['nobel'].value_counts()
# Out:
# 0    370
# 1     30
# Name: nobel, dtype: int64

# %%
# saving data cleaned to csv files
df_result.to_csv('data/data_cleaned.csv', index=False)
df_subset.to_csv('data/working_data.csv', index=False)
